# %% [markdown]
# ## Aula 1 -  Fazendo as primeiras visualizações

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('dados/monitoramento_tempo.csv')

# %%
df.head()
# Out:
#    temperatura  pressão  humidade  direção do vento  velocidade do vento  \
# 0   282.080000   1024.0      81.0               0.0                  0.0
# 1   282.080000   1024.0      81.0               0.0                  0.0
# 2   282.083252   1024.0      80.0               4.0                  0.0
# 3   282.091866   1024.0      80.0              18.0                  0.0
# 4   282.100481   1024.0      80.0              31.0                  0.0
#
#   dia_da_semana                 data
# 0       Domingo  2012-10-01 12:00:00
# 1       Domingo  2012-10-01 13:00:00
# 2       Domingo  2012-10-01 14:00:00
# 3       Domingo  2012-10-01 15:00:00
# 4       Domingo  2012-10-01 16:00:00

# %%
#expor mais dados
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   temperatura          45253 non-null  float64
#  1   pressão              45253 non-null  float64
#  2   humidade             45253 non-null  float64
#  3   direção do vento     45253 non-null  float64
#  4   velocidade do vento  45253 non-null  float64
#  5   dia_da_semana        45253 non-null  object
#  6   data                 45253 non-null  object
# dtypes: float64(5), object(2)
# memory usage: 2.4+ MB

# %%
#convertendo tipo data
df['data'] = pd.to_datetime(df['data'])

# %%
plt.plot(df['data'], df['temperatura'])

# %%
plt.figure(figsize=(15,8))
plt.plot(df['data'], df['temperatura'])

# %%
plt.figure(figsize=(15,8))
plt.plot(df['data'], df['temperatura'])
plt.title('Temperatura no tempo')
# Out:
# Text(0.5, 1.0, 'Temperatura no tempo')

# %%
#criando eixos
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df['data'], df['temperatura'])
eixo.set_title('Temperatura no momento')
# Out:
# Text(0.5, 1.0, 'Temperatura no momento')

# %%
#identificando eixos
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df['data'], df['temperatura'])

eixo.set_title('Temperatura no momento')
eixo.set_ylabel('Temperatura')
eixo.set_xlabel('Data')
# Out:
# Text(0.5, 0, 'Data')

# %%
#aumentar o tamanho da fonte
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df['data'], df['temperatura'])

eixo.set_title('Temperatura no momento', fontsize=25)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)
# Out:
# Text(0.5, 0, 'Data')

# %%
#legendas
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df['data'], df['temperatura'])

eixo.set_title('Temperatura no momento', fontsize=25)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)
eixo.legend(['temperatura'], loc = 'lower right', fontsize = 15)

# %%
#trocar cor do grafico
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df['data'], df['temperatura'], color= 'teal')

eixo.set_title('Temperatura no momento', fontsize=25)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)
eixo.legend(['temperatura'], loc = 'lower right', fontsize = 15)

# %% [markdown]
# ## Aula 2 - Customizando nossas visualizações

# %%
#espessura da linha e estilo
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df['data'], df['temperatura'], color= 'teal', lw = 0.3)

eixo.set_title('Temperatura no momento', fontsize=25)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)
eixo.legend(['temperatura'], loc = 'lower right', fontsize = 15)

# %%
#estilo da linha
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df['data'], df['temperatura'], color= 'teal', ls = 'dotted')

eixo.set_title('Temperatura no momento', fontsize=25)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)
eixo.legend(['temperatura'], loc = 'lower right', fontsize = 15)

# %%
import datetime

# %%
#limitar o intervalo dos dados
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df['data'], df['temperatura'], color= 'teal')

eixo.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
eixo.set_title('Temperatura no momento', fontsize=25)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)
eixo.legend(['temperatura'], loc = 'lower right', fontsize = 15)

# %%
#marcador
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df['data'], df['temperatura'], color= 'teal', marker='o')

eixo.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
eixo.set_title('Temperatura no momento', fontsize=25)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)
eixo.legend(['temperatura'], loc = 'lower right', fontsize = 15)

# %%
#grades
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df['data'], df['temperatura'], color= 'teal')

eixo.set_xlim(datetime.datetime(2014,1,1), datetime.datetime(2015,1,1))
eixo.set_title('Temperatura no momento', fontsize=25)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)
eixo.legend(['temperatura'], loc = 'lower right', fontsize = 15)
eixo.grid(True)

# %%
fig = plt.figure(figsize=(15,8))

eixo = fig.add_axes([0,0,1,1])
eixo2 = fig.add_axes([0.1,0.5,0.4,0.4])

# %%
#acrescentar infos
fig = plt.figure(figsize=(15,8))

eixo = fig.add_axes([0,0,1,1])
eixo2 = fig.add_axes([0.1,0.5,0.4,0.4])

eixo.grid(True)
eixo.plot(df['data'], df['temperatura'], color='teal')
eixo.set_title('Temperatura no momento', fontsize=25, pad=20)
eixo.legend(['temperatura'], loc='best', fontsize=15)

# %%
#acrescentar eixo2
fig = plt.figure(figsize=(15,8))

eixo = fig.add_axes([0,0,1,1])
eixo2 = fig.add_axes([0.1,0.5,0.4,0.4])

eixo.grid(True)
eixo.plot(df['data'], df['temperatura'], color='teal')
eixo.set_title('Temperatura no momento', fontsize=25, pad=20)
eixo.legend(['temperatura'], loc='best', fontsize=15)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)

eixo2.plot(df['data'], df['temperatura'], color = 'lightseagreen')
eixo2.set_title('Temperatura no momento', fontsize=15)
eixo2.legend(['temperatura'], loc='best', fontsize=8)
eixo2.set_ylabel('Temperatura', fontsize=10)
eixo2.set_xlabel('Data', fontsize=10)
# Out:
# Text(0.5, 0, 'Data')

# %%
#colocar no outro lado 
fig = plt.figure(figsize=(15,8))

eixo = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.7, 0.65, 0.3, 0.3])

eixo.grid(True)
eixo.plot(df['data'], df['temperatura'], color='teal')
eixo.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eixo.set_title('Temperatura em 2014', fontsize=25, pad=20)
eixo.legend(['temperatura'], loc='lower right', fontsize=15)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)

eixo2.plot(df['data'], df['temperatura'], color = 'lightseagreen')
eixo2.set_title('Temperatura no momento', fontsize=15)
eixo2.legend(['temperatura'], loc='best', fontsize=8)
eixo2.set_ylabel('Temperatura', fontsize=10)
eixo2.set_xlabel('Data', fontsize=10)
eixo2.grid(True)

# %%
#modificar os eixos
fig = plt.figure(figsize=(15,8))

eixo = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.7, 0.65, 0.3, 0.3])

eixo.grid(True)
eixo.plot(df['data'], df['temperatura'], color='teal')
eixo.set_xlim(datetime.datetime(2014,5,1),datetime.datetime(2014,6,1))
eixo.set_title('Temperatura em 2014', fontsize=25, pad=20)
eixo.legend(['temperatura'], loc='lower right', fontsize=15)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)

eixo2.plot(df['data'], df['temperatura'], color = 'lightseagreen')
eixo2.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eixo2.set_title('Temperatura no momento', fontsize=15)
eixo2.legend(['temperatura'], loc='best', fontsize=8)
eixo2.set_ylabel('Temperatura', fontsize=10)
eixo2.set_xlabel('Data', fontsize=10)
eixo2.grid(True)

# %%
#Limites do eixo ylim e mudança de titulos
fig = plt.figure(figsize=(15,8))

eixo = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.7, 0.65, 0.3, 0.3])

eixo.grid(True)
eixo.plot(df['data'], df['temperatura'], color='teal')
eixo.set_xlim(datetime.datetime(2014,5,1),datetime.datetime(2014,6,1))
eixo.set_ylim(270,320)
eixo.set_title('Temperatura em maio/2014', fontsize=25, pad=20)
eixo.legend(['temperatura'], loc='lower right', fontsize=15)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)

eixo2.plot(df['data'], df['temperatura'], color = 'lightseagreen')
eixo2.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eixo2.set_title('Temperatura em 2014', fontsize=15)
eixo2.legend(['temperatura'], loc='best', fontsize=8)
eixo2.set_ylabel('Temperatura', fontsize=10)
eixo2.set_xlabel('Data', fontsize=10)
eixo2.grid(True)

# %%
#associar/filtrar informações pela cor

fig = plt.figure(figsize=(15,8))

eixo = fig.add_axes([0, 0, 1, 1])
eixo2 = fig.add_axes([0.7, 0.65, 0.3, 0.3])

eixo.grid(True)
eixo.plot(df['data'], df['temperatura'], color='lightseagreen')
eixo.set_xlim(datetime.datetime(2014,5,1),datetime.datetime(2014,6,1))
eixo.set_ylim(270,320)
eixo.set_title('Temperatura em maio/2014', fontsize=25, pad=20)
eixo.legend(['temperatura'], loc='lower right', fontsize=15)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data', fontsize=20)

#criando filtros da esq e dir(grafico pequeno)
azul_esquerda = df['data'] < datetime.datetime(2014,5,1)
azul_direita = df['data'] > datetime.datetime(2014,6,1)

eixo2.plot(df['data'], df['temperatura'], color = 'lightseagreen')
eixo2.plot(df[azul_esquerda]['data'], df[azul_esquerda]['temperatura'], color='teal')
eixo2.plot(df[azul_direita]['data'], df[azul_direita]['temperatura'], color='teal')
eixo2.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eixo2.set_title('Temperatura em 2014', fontsize=15)
eixo2.legend(['temperatura'], loc='best', fontsize=8)
eixo2.set_ylabel('Temperatura', fontsize=10)
eixo2.set_xlabel('Data', fontsize=10)
eixo2.grid(True)

# %%
#identificar os pontos maximos e minimos (uso de anotações e limites com linhas)

fig = plt.figure(figsize = (15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.plot(df['data'], df['temperatura'], color='teal')
eixo.set_title('Temperatura no momento', fontsize=25, pad=20)
eixo.set_xlabel('Data', fontsize=20)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15)
eixo.grid(True)

#linhas
eixo.axhline(max(df['temperatura']), color = 'red', linestyle='--')
eixo.axhline(min(df['temperatura']), color = 'red', linestyle='--')

# %%
#anotações (x, y)
fig = plt.figure(figsize = (15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.plot(df['data'], df['temperatura'], color='teal')
eixo.set_title('Temperatura no momento', fontsize=25, pad=20)
eixo.set_xlabel('Data', fontsize=20)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15)
eixo.grid(True)

#anotações
x1 = df['data'][df['temperatura'].idxmax()]
y1 = max(df['temperatura'])

eixo.annotate("Máximo", xy = (x1, y1), fontsize=18)

#linhas
eixo.axhline(max(df['temperatura']), color = 'red', linestyle='--')
eixo.axhline(min(df['temperatura']), color = 'red', linestyle='--')

# %%
#mudar o local do maximo e setas

fig = plt.figure(figsize = (15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.plot(df['data'], df['temperatura'], color='teal')
eixo.set_title('Temperatura no momento', fontsize=25, pad=20)
eixo.set_xlabel('Data', fontsize=20)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15)
eixo.grid(True)

#anotações
x1 = df['data'][df['temperatura'].idxmax()]
y1 = max(df['temperatura'])

#seta (x desloca o max e minimo)
x2 = df['data'][df['temperatura'].idxmax() - 7000]
y2 = max(df['temperatura']) - 5 

eixo.annotate("Máximo", xy = (x1, y1), fontsize=18, xytext=(x2, y2), arrowprops = dict(facecolor='k'))

eixo.axhline(max(df['temperatura']), color = 'red', linestyle='--')
eixo.axhline(min(df['temperatura']), color = 'red', linestyle='--')

# %%
#anotação minimo
fig = plt.figure(figsize = (15,8))
eixo = fig.add_axes([0,0,1,1])

eixo.plot(df['data'], df['temperatura'], color='teal')
eixo.set_title('Temperatura no momento', fontsize=25, pad=20)
eixo.set_xlabel('Data', fontsize=20)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15)
eixo.grid(True)

#anotações maximo
x1 = df['data'][df['temperatura'].idxmax()]
y1 = max(df['temperatura'])

#seta (x desloca a posição do max)
x2 = df['data'][df['temperatura'].idxmax() - 7000]
y2 = max(df['temperatura']) - 5 

eixo.annotate("Máximo", xy = (x1, y1), fontsize=18, xytext=(x2, y2), arrowprops = dict(facecolor='k'))

#anotações minimo
x1 = df['data'][df['temperatura'].idxmin()]
y1 = min(df['temperatura'])

#seta (x desloca a posição do minimo)
x2 = df['data'][df['temperatura'].idxmin() - 7000]
y2 = min(df['temperatura']) + 5 

eixo.annotate("Mínimo", xy = (x1, y1), fontsize=18, xytext=(x2, y2), arrowprops = dict(facecolor='k'))

#linhas
eixo.axhline(max(df['temperatura']), color = 'red', linestyle='--')
eixo.axhline(min(df['temperatura']), color = 'red', linestyle='--')

# %%
#criar um gráfico de dia da semana x média de temperatura

temperatura_por_dia_da_semana = df.groupby('dia_da_semana')['temperatura'].mean()
nome_dias = ['Domingo', 'Segunda', 'Terça', 'Quarta', 'Quinta', 'Sexta', 'Sábado']
temperatura_por_dia_da_semana = temperatura_por_dia_da_semana[nome_dias]
temperatura_por_dia_da_semana
# Out:
# dia_da_semana
# Domingo    285.009095
# Segunda    284.985382
# Terça      284.892811
# Quarta     284.998290
# Quinta     285.000643
# Sexta      285.060886
# Sábado     285.003316
# Name: temperatura, dtype: float64

# %%
fig = plt.figure(figsize = (5,4))
eixo = fig.add_axes([0,0,1,1])

indice = range(len(temperatura_por_dia_da_semana))

eixo.bar(indice, temperatura_por_dia_da_semana)
eixo.set_title('Temperatura por dia da Semana', fontsize=15, pad=10)
eixo.set_xlabel('Dia da semana', fontsize=15)
eixo.set_ylabel('Temperatura média', fontsize=15)
# Out:
# Text(0, 0.5, 'Temperatura média')

# %%
#mudar o nome dos indices
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])
indice = range(len(temperatura_por_dia_da_semana))

eixo.bar(indice, temperatura_por_dia_da_semana)
eixo.set_title('Temperatura por dia da semana', fontsize=15, pad=10)
eixo.set_xlabel('Dia da semana', fontsize=15)
eixo.set_ylabel('Temperatura média', fontsize=15)
eixo.set_xticks(indice)
eixo.set_xticklabels(nome_dias)
# Out:
# [Text(0, 0, 'Domingo'),
#  Text(1, 0, 'Segunda'),
#  Text(2, 0, 'Terça'),
#  Text(3, 0, 'Quarta'),
#  Text(4, 0, 'Quinta'),
#  Text(5, 0, 'Sexta'),
#  Text(6, 0, 'Sábado')]

# %%
#cor
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])
indice = range(len(temperatura_por_dia_da_semana))
cores = ['black', 'red', 'green', 'blue', 'yellow', 'orange', 'magenta']

eixo.bar(indice, temperatura_por_dia_da_semana, color=cores)
eixo.set_title('Temperatura por dia da semana', fontsize=15, pad=10)
eixo.set_xlabel('Dia da semana', fontsize=15)
eixo.set_ylabel('Temperatura média', fontsize=15)
eixo.set_xticks(indice)
eixo.set_xticklabels(nome_dias)
# Out:
# [Text(0, 0, 'Domingo'),
#  Text(1, 0, 'Segunda'),
#  Text(2, 0, 'Terça'),
#  Text(3, 0, 'Quarta'),
#  Text(4, 0, 'Quinta'),
#  Text(5, 0, 'Sexta'),
#  Text(6, 0, 'Sábado')]

# %%
#bordas nas barras

fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

indice = range(len(temperatura_por_dia_da_semana))
cores = ['black', 'red', 'green', 'blue', 'yellow', 'orange', 'magenta']

eixo.bar(indice, temperatura_por_dia_da_semana, color=cores, edgecolor='black')
eixo.set_title('Temperatura por dia da semana', fontsize=15, pad=10)
eixo.set_xlabel('Dia da semana', fontsize=15)
eixo.set_ylabel('Temperatura média', fontsize=15)
eixo.set_xticks(indice)
eixo.set_xticklabels(nome_dias)
# Out:
# [Text(0, 0, 'Domingo'),
#  Text(1, 0, 'Segunda'),
#  Text(2, 0, 'Terça'),
#  Text(3, 0, 'Quarta'),
#  Text(4, 0, 'Quinta'),
#  Text(5, 0, 'Sexta'),
#  Text(6, 0, 'Sábado')]

# %%
#pizza

fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

eixo.pie(temperatura_por_dia_da_semana, labels = temperatura_por_dia_da_semana.index)
eixo.set_title('Temperatura por dia da semana', fontsize=15, pad=10)
# Out:
# Text(0.5, 1.0, 'Temperatura por dia da semana')

# %%
# valores em %

fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

eixo.pie(temperatura_por_dia_da_semana, labels = temperatura_por_dia_da_semana.index,
        autopct='%.1f%%')
eixo.set_title('Temperatura por dia da semana', fontsize=15, pad=10)
# Out:
# Text(0.5, 1.0, 'Temperatura por dia da semana')

# %%
#destacar o final de semana (explode)

fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

explodir=[0.1,0,0,0,0,0.1,0.1]

eixo.pie(temperatura_por_dia_da_semana, labels = temperatura_por_dia_da_semana.index,
        autopct='%.1f%%', explode=explodir)
eixo.set_title('Temperatura por dia da semana', fontsize=15, pad=10)
# Out:
# Text(0.5, 1.0, 'Temperatura por dia da semana')

# %%
#sombra nessa explosão

fig = plt.figure(figsize=(5,6))
eixo = fig.add_axes([0,0,1,1])

explodir=[0.1,0,0,0,0,0.1,0.1]

eixo.pie(temperatura_por_dia_da_semana, labels = temperatura_por_dia_da_semana.index,
        autopct='%.1f%%', explode=explodir, shadow=True)
eixo.set_title('Temperatura por dia da semana', fontsize=15, pad=10)
# Out:
# Text(0.5, 1.0, 'Temperatura por dia da semana')
