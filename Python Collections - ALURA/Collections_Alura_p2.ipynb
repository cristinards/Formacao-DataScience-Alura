# %% [markdown]
# ### Cap 1: Conjuntos

# %%
usuarios_data_science = [15,23,43,56]
usuarios_machine_learning = [13,23,56,42]

# %%
assistiram = usuarios_data_science.copy()
assistiram.extend(usuarios_machine_learning)
assistiram
# Out:
# [15, 23, 43, 56, 13, 23, 56, 42]

# %%
len(assistiram)
# Out:
# 8

# %%
set(assistiram) #transformar a lista em conjuntos
# Out:
# {13, 15, 23, 42, 43, 56}

# %%
 set([1,2,3,1])
# Out:
# {1, 2, 3}

# %%
{4,1,2,3,1}
# Out:
# {1, 2, 3, 4}

# %%
type({1,2})
# Out:
# set

# %%
usuarios_data_science = {15,23,43,56}
usuarios_machine_learning = {13,23,56,42}
#onde a ordem nao importa = usa conjunto

usuarios_machine_learning
# Out:
# {13, 23, 42, 56}

# %%
for usuario in assistiram:
  print(usuario)
# Out:
# 15
# 23
# 43
# 56
# 13
# 23
# 56
# 42

# %%
usuarios_data_science = {15,23,43,56}
usuarios_machine_learning = {13,23,56,42}

# %%
usuarios_data_science | usuarios_machine_learning #op de uniao - OU
# Out:
# {13, 15, 23, 42, 43, 56}

# %%
usuarios_data_science & usuarios_machine_learning # E
# Out:
# {23, 56}

# %%
usuarios_data_science - usuarios_machine_learning # nao está
# Out:
# {15, 43}

# %%
fezds_mas_nao_fezml = usuarios_data_science - usuarios_machine_learning
15 in fezds_mas_nao_fezml
# Out:
# True

# %%
23 in fezds_mas_nao_fezml
# Out:
# False

# %%
usuarios_data_science ^ usuarios_machine_learning
# Out:
# {13, 15, 42, 43}

# %% [markdown]
# ### Cap 2: Operações

# %%
usuarios = {1,5,76,34,52,13,17}
len(usuarios)
# Out:
# 7

# %%
usuarios.add(13)
len(usuarios)
# Out:
# 7

# %%
usuarios.add(765)
len(usuarios)
# Out:
# 8

# %%
usuarios
# Out:
# {1, 5, 13, 17, 34, 52, 76, 765}

# %%
frozenset(usuarios) #devolve outro conjunto - nao se adiciona mais elementos
usuarios
# Out:
# {1, 5, 13, 17, 34, 52, 76, 765}

# %%
type(usuarios)
# Out:
# set

# %%
meu_texto = "Bem vindo meu nome e joao e eu gosto muito de nomes e tenho o meu cachorro e gosto muito de gato"
meu_texto.split()
# Out:
# ['Bem',
#  'vindo',
#  'meu',
#  'nome',
#  'e',
#  'joao',
#  'e',
#  'eu',
#  'gosto',
#  'muito',
#  'de',
#  'nomes',
#  'e',
#  'tenho',
#  'o',
#  'meu',
#  'cachorro',
#  'e',
#  'gosto',
#  'muito',
#  'de',
#  'gato']

# %%
set(meu_texto.split()) #transformar em conjunto sem letras repetidas
# Out:
# {'Bem',
#  'cachorro',
#  'de',
#  'e',
#  'eu',
#  'gato',
#  'gosto',
#  'joao',
#  'meu',
#  'muito',
#  'nome',
#  'nomes',
#  'o',
#  'tenho',
#  'vindo'}

# %% [markdown]
# ### Cap 3: Dicionarios

# %%
#quantas vezes uma palavra x aparece - Mapa
aparicoes = {
    "Guilherme": 1,
    "cachorro": 2,
    "nome": 2,
    "vindo": 1
}

# %%
type(aparicoes)
# Out:
# dict

# %%
aparicoes["Guilherme"]
# Out:
# 1

# %%
aparicoes["cachorro"]
# Out:
# 2

# %%
aparicoes.get("xpto",0) #palavra ou devolve x
# Out:
# 0

# %%
aparicoes.get("cachorro",0)
# Out:
# 2

# %%
aparicoes = dict(Guilherme = 2, cachorro = 1)
aparicoes
# Out:
# {'Guilherme': 2, 'cachorro': 1}

# %%
aparicoes = {
    "Guilherme": 1,
    "cachorro": 2,
    "nome": 2,
    "vindo": 1
}

# %%
aparicoes["Carlos"] = 1 #acrescentar

# %%
aparicoes
# Out:
# {'Carlos': 1, 'Guilherme': 1, 'cachorro': 2, 'nome': 2, 'vindo': 1}

# %%
aparicoes["Carlos"] = 2

# %%
aparicoes
# Out:
# {'Carlos': 2, 'Guilherme': 1, 'cachorro': 2, 'nome': 2, 'vindo': 1}

# %%
del aparicoes["Carlos"] #remover

# %%
aparicoes
# Out:
# {'Guilherme': 1, 'cachorro': 2, 'nome': 2, 'vindo': 1}

# %%
"cachorro" in aparicoes #verificar se está dentro
# Out:
# True

# %%
"Carlos" in aparicoes
# Out:
# False

# %%
for elemento in aparicoes:
  print(elemento)
# Out:
# Guilherme
# cachorro
# nome
# vindo

# %%
for elemento in aparicoes.keys():
  print(elemento)
# Out:
# Guilherme
# cachorro
# nome
# vindo

# %%
for elemento in aparicoes.values():
  print(elemento)
# Out:
# 1
# 2
# 2
# 1

# %%
1 in aparicoes.values()
# Out:
# True

# %%
for elemento in aparicoes.keys():
  valor = aparicoes[elemento]
  print(elemento, valor)
# Out:
# Guilherme 1
# cachorro 2
# nome 2
# vindo 1

# %%
for elemento in aparicoes.items():
  print(elemento)
# Out:
# ('Guilherme', 1)
# ('cachorro', 2)
# ('nome', 2)
# ('vindo', 1)

# %%
for chave, valor in aparicoes.items():
  print(chave, "=", valor)
# Out:
# Guilherme = 1
# cachorro = 2
# nome = 2
# vindo = 1

# %%
["palavra {}".format(chave) for chave in aparicoes.keys()]
# Out:
# ['palavra Guilherme', 'palavra cachorro', 'palavra nome', 'palavra vindo']

# %% [markdown]
# ### Cap 4: Variações de dicionarios

# %%
meu_texto = "Bem vindo meu nome e joao e eu gosto muito de nomes e tenho o meu cachorro e gosto muito de gato"
meu_texto = meu_texto.lower()
aparicoes = {}
for palavra in meu_texto.split():
  ate_agora = aparicoes.get(palavra, 0)
  aparicoes[palavra] = ate_agora+1

aparicoes
# Out:
# {'bem': 1,
#  'cachorro': 1,
#  'de': 2,
#  'e': 4,
#  'eu': 1,
#  'gato': 1,
#  'gosto': 2,
#  'joao': 1,
#  'meu': 2,
#  'muito': 2,
#  'nome': 1,
#  'nomes': 1,
#  'o': 1,
#  'tenho': 1,
#  'vindo': 1}

# %%
from collections import defaultdict

aparicoes = defaultdict(int)

for palavra in meu_texto.split():
  ate_agora = aparicoes[palavra]
  aparicoes[palavra] = ate_agora+1

aparicoes
# Out:
# defaultdict(int,
#             {'bem': 1,
#              'cachorro': 1,
#              'de': 2,
#              'e': 4,
#              'eu': 1,
#              'gato': 1,
#              'gosto': 2,
#              'joao': 1,
#              'meu': 2,
#              'muito': 2,
#              'nome': 1,
#              'nomes': 1,
#              'o': 1,
#              'tenho': 1,
#              'vindo': 1})

# %%
dicionario = defaultdict(int)
dicionario ["Guilherme"]
# Out:
# 0

# %%
dicionario ["Guilherme"] = 15
dicionario ["Guilherme"]
# Out:
# 15

# %%
#Simplificando

from collections import defaultdict

aparicoes = defaultdict(int)

for palavra in meu_texto.split():
  aparicoes[palavra] += 1

aparicoes
# Out:
# defaultdict(int,
#             {'bem': 1,
#              'cachorro': 1,
#              'de': 2,
#              'e': 4,
#              'eu': 1,
#              'gato': 1,
#              'gosto': 2,
#              'joao': 1,
#              'meu': 2,
#              'muito': 2,
#              'nome': 1,
#              'nomes': 1,
#              'o': 1,
#              'tenho': 1,
#              'vindo': 1})

# %%
class Conta:
  def __init__(self):
    print("Imprimindo uma conta")

# %%
contas = defaultdict(Conta)
contas[15]
# Out:
# Imprimindo uma conta

# %%
contas[17]
# Out:
# Imprimindo uma conta

# %%
from collections import Counter

aparicoes = Counter( meu_texto.split())

aparicoes
# Out:
# Counter({'bem': 1,
#          'cachorro': 1,
#          'de': 2,
#          'e': 4,
#          'eu': 1,
#          'gato': 1,
#          'gosto': 2,
#          'joao': 1,
#          'meu': 2,
#          'muito': 2,
#          'nome': 1,
#          'nomes': 1,
#          'o': 1,
#          'tenho': 1,
#          'vindo': 1})

# %% [markdown]
# ### Cap 5: Praticando

# %%
#Contador de diversas condições

texto1 = """
  O gerenciamento de produtos remonta a 1931 . A Hewlett Packard foi uma das primeiras empresas de tecnologia a implementar esse trabalho e se organizar por produtos na década de 1940. A maioria das empresas do Vale do Silício teve gerentes de produto desde o início, e muitos dos meus amigos que trabalharam lá nas décadas de 80 e 90 eram, de fato, gerentes de produto. Portanto, essa disciplina não é nova, mas está evoluindo rapidamente à medida que mais empresas começam a se transformar em organizações de software e a se estruturar em torno de produtos.Scrum entrou em cena pouco antes de o Manifesto Ágil ser escrito em 2001. Ele introduziu o conceito de Dono do Produto. Era uma pessoa que atuava como proxy do cliente e informava aos desenvolvedores os requisitos para o que precisava ser construído. No início, quando muitos dos criadores desses processos trabalhavam como consultores em empresas, o Dono do Produto era o cliente - uma pessoa interna da empresa que se sentava com a equipe e priorizava o acúmulo de trabalho. Na verdade, os objetivos de aprendizagem de 2017 para a Certificação de Dono do Produto Certificado Scrum da Scrum Alliance afirmam: “Ensine que o papel do Dono do Produto é normalmente desempenhado pelo cliente, ou representante do cliente, como um gerente de produto”. 
"""

texto2 = """
O termo CHA – Conhecimento, Habilidade e Atitude foi desenvolvido por Scott B. Parry em seu livro “The Quest For Competencies” (a busca por competências, em português), publicado em 1996. Esses três elementos representam o tripé das competências de uma pessoa, algo que se manifesta através da sua forma de pensar, sentir e agir, e tem um grande impacto sobre o seu desempenho profissional. Continue acompanhando para saber mais como desenvolver essas competências para construir uma carreira de sucesso.
Conhecimento: representam as habilidades cognitivas utilizadas para processar e reter informações. Fatos e conceitos aprendidos entram dentro desta categoria;
Habilidade: neste tópico, o que conta são as habilidades que permitem colocar em prática o que foi aprendido. A ação que representa bem esta categoria é aprender a fazer algo;
Atitude: aqui estão contidos os sentimentos que levam uma pessoa a desejar colocar em prática o conhecimento e as habilidades adquiridas. Desenvolver um ponto de vista com base em informações obtidas faz parte da atitude.

"""
texto3 = """
O gerenciamento de projetos tem três conceitos bastante importantes para os profissionais que desejam se aventurar nesta área, são eles: quem é o PMI (Project Management Institute), o que é o PMBoK (Project Management Base of Knowledment) e, por fim, o que é o PMP (Project Management Professional).
O PMI é uma antiga e bastante importante instituição que deu origem tanto ao PMBoK quanto ao PMP. O Guia PMBoK é um guia de boas práticas. Verificamos que ele é apenas um guia e não uma metodologia, não é algo “amarrado”. Nele são apresentados diversos processos e ferramentas, mas não se usa tudo, e sim conforme a necessidade do projeto. O guia não determina como será gerenciado um projeto, ele apenas sugere boas práticas. A equipe determina quais processos são apropriados, ou seja, há processos que em determinado projeto são inapropriados. O PMP é uma certificação criada pelo PMI para atestar o conhecimento e a experiência dos gerentes de projetos a fim de credenciá-los como um gerente de projetos apto a exercer a profissão.
"""

# %%
for x in "Guilherme":
  print(x)
# Out:
# G
# u
# i
# l
# h
# e
# r
# m
# e

# %%
aparicoes = Counter(texto1.lower())
total_de_caracteres = sum(aparicoes.values())

for letra, frequencia in aparicoes.items():
  tupla = (letra, frequencia / total_de_caracteres)
  print(tupla)
# Out:
# ('\n', 0.0015278838808250573)
# (' ', 0.16959511077158135)
# ('o', 0.09243697478991597)
# ('g', 0.007639419404125287)
# ('e', 0.1092436974789916)
# ('r', 0.059587471352177235)
# ('n', 0.04201680672268908)
# ('c', 0.02826585179526356)
# ('i', 0.04125286478227655)
# ('a', 0.08403361344537816)
# ('m', 0.03819709702062643)
# ('t', 0.04430863254392666)
# ('d', 0.053475935828877004)
# ('p', 0.029029793735676088)
# ('u', 0.03132161955691368)
# ('s', 0.059587471352177235)
# ('1', 0.0038197097020626434)
# ('9', 0.002291825821237586)
# ('3', 0.0007639419404125286)
# ('.', 0.006875477463712758)
# ('h', 0.004583651642475172)
# ('w', 0.0015278838808250573)
# ('l', 0.019862490450725745)
# ('k', 0.0007639419404125286)
# ('f', 0.006875477463712758)
# ('b', 0.0038197097020626434)
# ('z', 0.0038197097020626434)
# ('é', 0.0030557677616501145)
# ('4', 0.0007639419404125286)
# ('0', 0.004583651642475172)
# ('v', 0.0106951871657754)
# ('í', 0.0030557677616501145)
# (',', 0.007639419404125287)
# ...

# %%
def analisa_frequencia_de_letras(texto):
  aparicoes = Counter(texto1.lower())
  total_de_caracteres = sum(aparicoes.values())

  proporcoes = [(letra, frequencia/total_de_caracteres) for letra, frequencia in aparicoes.items()]
  proporcoes = Counter(dict(proporcoes))
  mais_comuns = proporcoes.most_common(10)
  for caractere, proporcao in mais_comuns:
    print("{} => {:.2f}%".format(caractere, proporcao * 100))

# %%
analisa_frequencia_de_letras(texto1)
# Out:
#   => 16.96%
# e => 10.92%
# o => 9.24%
# a => 8.40%
# r => 5.96%
# s => 5.96%
# d => 5.35%
# t => 4.43%
# n => 4.20%
# i => 4.13%

# %%
analisa_frequencia_de_letras(texto2)
# Out:
#   => 16.96%
# e => 10.92%
# o => 9.24%
# a => 8.40%
# r => 5.96%
# s => 5.96%
# d => 5.35%
# t => 4.43%
# n => 4.20%
# i => 4.13%

# %%
analisa_frequencia_de_letras(texto3)
# Out:
#   => 16.96%
# e => 10.92%
# o => 9.24%
# a => 8.40%
# r => 5.96%
# s => 5.96%
# d => 5.35%
# t => 4.43%
# n => 4.20%
# i => 4.13%
