# %% [markdown]
# ### Cap 1: Listas e operações

# %%
idade1 = 39
idade2 = 30
idade3 = 27
idade4 = 18

print(idade1)
print(idade2)
print(idade3)
print(idade4)
# Out:
# 39
# 30
# 27
# 18

# %%
idades = [39,30,27,18]

# %%
type (idades)
# Out:
# list

# %%
len(idades)
# Out:
# 4

# %%
idades[0]
# Out:
# 39

# %%
idades
# Out:
# [39, 30, 27, 18]

# %%
idades[1]
idades[2]
idades[3]
# Out:
# 18

# %%
print(idades[1])
print(idades[2])
print(idades[3])
# Out:
# 30
# 27
# 18

# %%
#acrescentar ao final da lista
idades.append(15)

# %%
idades
# Out:
# [39, 30, 27, 18, 15]

# %%
idades[4]
# Out:
# 15

# %%
for idade in idades:
  print(idade)
# Out:
# 39
# 30
# 27
# 18
# 15

# %%
idades.remove(30)

# %%
idades
# Out:
# [39, 27, 18, 15]

# %%
idades.append(15)

# %%
idades
# Out:
# [39, 27, 18, 15, 15]

# %%
idades.remove(15)

# %%
idades
# Out:
# [39, 27, 18, 15]

# %%
idades.append(27)
idades.remove(27)
idades
# Out:
# [39, 18, 15, 27, 27]

# %%
idades.remove(27)
idades
# Out:
# [39, 18, 15, 27]

# %%
15 in idades
# Out:
# True

# %%
28 in idades
# Out:
# False

# %%
if 15 in idades:
  idades.remove(15)

# %%
idades
# Out:
# [39, 30, 27, 18]

# %%
idades.append(19)

# %%
idades
# Out:
# [39, 30, 27, 18, 19]

# %%
idades.insert(0,20)
idades
# Out:
# [20, 39, 30, 27, 18, 19]

# %%
idades = [20,39,18]

# %%
idades.append([27,19])

# %%
idades
# Out:
# [20, 39, 18, [27, 19]]

# %%
for elemento in idades:
  print("recebi o elemento", elemento)
# Out:
# recebi o elemento 20
# recebi o elemento 39
# recebi o elemento 18
# recebi o elemento [27, 19]

# %%
idades = [20,39,18]
idades.extend([27,19])
idades
# Out:
# [20, 39, 18, 27, 19]

# %%
for idade in idades:
  print (idade+1)
# Out:
# 21
# 40
# 19
# 28
# 20

# %%
idades_no_ano_que_vem = []
for idade in idades:
  idades_no_ano_que_vem.append(idade+1)

# %%
idades_no_ano_que_vem
# Out:
# [21, 40, 19, 28, 20]

# %%
idades_no_ano_que_vem = [(idade+1)for idade in idades]
idades_no_ano_que_vem
# Out:
# [21, 40, 19, 28, 20]

# %%
[(idade)for idade in idades if idade > 21]
# Out:
# [39, 27]

# %%
idades
# Out:
# [20, 39, 18, 27, 19]

# %%
def proximo_ano(idade):
  return idade + 1

[proximo_ano(idade) for idade in idades if idade>21]
# Out:
# [40, 28]

# %%
def faz_processamento_de_visualizacao(lista):
  print(len(lista))
  lista.append(13)

# %%
idades = [16,21,29,56,43]
faz_processamento_de_visualizacao(idades)
idades
# Out:
# 5
# [16, 21, 29, 56, 43, 13]

# %%
def faz_processamento_de_visualizacao(lista = []):
  print(len(lista))
  lista.append(13)

# %%
faz_processamento_de_visualizacao()
# Out:
# 0

# %%
faz_processamento_de_visualizacao()
# Out:
# 1

# %%
faz_processamento_de_visualizacao()
# Out:
# 2

# %%
faz_processamento_de_visualizacao()
# Out:
# 3

# %%
def faz_processamento_de_visualizacao(lista = []):
  print(len(lista))
  print(lista)
  lista.append(13)

# %%
faz_processamento_de_visualizacao()
# Out:
# 0
# []

# %%
faz_processamento_de_visualizacao()
# Out:
# 1
# [13]

# %%
faz_processamento_de_visualizacao()
# Out:
# 2
# [13, 13]

# %%
faz_processamento_de_visualizacao()
# Out:
# 3
# [13, 13, 13]

# %%
def faz_processamento_de_visualizacao(lista = None):
 if lista == None:
   lista = list()
   print (len(lista))
   print(lista)
   lista.append(13)

# %%
faz_processamento_de_visualizacao()
faz_processamento_de_visualizacao()
faz_processamento_de_visualizacao()
faz_processamento_de_visualizacao()
# Out:
# 0
# []
# 0
# []
# 0
# []
# 0
# []

# %%
########################################################################

# %% [markdown]
# ### Cap 2 : Tuplas  e Objetos Próprios

# %%
class ContaCorrente:
  def __init__(self, codigo):
    self.codigo = codigo
    self.saldo = 0

  def deposita(self, valor):
    self.saldo+=valor

  def __str__(self):
    return "[>> Codigo: {} Saldo: {} <<]".format(self.codigo, self.saldo)

# %%
contaG = ContaCorrente(15)
print(contaG)
# Out:
# [>> Codigo: 15 Saldo: 0 <<]

# %%
contaG.deposita(500)
print(contaG)
# Out:
# [>> Codigo: 15 Saldo: 500 <<]

# %%
contaD = ContaCorrente(47865)
contaD.deposita(1000)
print(contaD)
# Out:
# [>> Codigo: 47865 Saldo: 1000 <<]

# %%
contas = [contaG, contaD]
for conta in contas:
  print(conta)
# Out:
# [>> Codigo: 15 Saldo: 500 <<]
# [>> Codigo: 47865 Saldo: 1000 <<]

# %%
contas = [contaG, contaD, contaG]

# %%
print(contas[0])
# Out:
# [>> Codigo: 15 Saldo: 600 <<]

# %%
contaG.deposita(100)

# %%
print(contaG)
# Out:
# [>> Codigo: 15 Saldo: 600 <<]

# %%
print(contas[2])
# Out:
# [>> Codigo: 15 Saldo: 600 <<]

# %%
contas[2].deposita(300)
print (contaG)
# Out:
# [>> Codigo: 15 Saldo: 900 <<]

# %%
def deposita_para_todas(contas):
  for conta in contas:
    conta.deposita(100)

contas = [contaG, contaD]
print(contas[0], contas[1])
deposita_para_todas(contas)
print(contas[0], contas[1])
# Out:
# [>> Codigo: 15 Saldo: 1100 <<] [>> Codigo: 47865 Saldo: 1200 <<]
# [>> Codigo: 15 Saldo: 1200 <<] [>> Codigo: 47865 Saldo: 1300 <<]

# %%
contas.insert(0,76)
print(contas[0], contas[1], contas[2])
# Out:
# 76 [>> Codigo: 15 Saldo: 1200 <<] [>> Codigo: 47865 Saldo: 1300 <<]

# %%
deposita_para_todas(contas)
print(contas[0], contas[1], contas[2])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-92ac4487eece> in <module>()
# ----> 1 deposita_para_todas(contas)
#       2 print(contas[0], contas[1], contas[2])
#
# <ipython-input-78-be4300543e91> in deposita_para_todas(contas)
#       1 def deposita_para_todas(contas):
#       2   for conta in contas:
# ----> 3     conta.deposita(100)
#       4
#       5 contas = [contaG, contaD]
#
# AttributeError: 'int' object has no attribute 'deposita'

# %%
contaG = (15,1000)
contaG[1]
# Out:
# 1000

# %%
def deposita(conta):
  novo_saldo = conta[1]+100
  codigo = conta[0]
  return(codigo, novo_saldo)

# %%
deposita(contaG)
# Out:
# (15, 1100)

# %%
contaG
# Out:
# (15, 1000)

# %%
contaG = deposita(contaG)
contaG
# Out:
# (15, 1100)

# %%
guilherme = ('Guilherme', 37, 1981)
daniela = ('Daniela', 31, 1987)
paulo = ('Paulo', 39, 1979)

# %%
usuarios = [guilherme, daniela, paulo]
usuarios
# Out:
# [('Guilherme', 37, 1981), ('Daniela', 31, 1987), ('Paulo', 39, 1979)]

# %%
#usuarios[0][0] = 'Guilherme Silveira' - nao muda o valor pois é uma tupla
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-e9cc663c16db> in <module>()
# ----> 1 usuarios[0][0] = 'Guilherme Silveira'
#
# TypeError: 'tuple' object does not support item assignment

# %%
contaG = ContaCorrente(15)
contaG.deposita(500)
contaD= ContaCorrente(234876)
contaD.deposita(1000)

contas = (contaG, contaD)

contas
# Out:
# (<__main__.ContaCorrente at 0x7f808f821610>,
#  <__main__.ContaCorrente at 0x7f808f8214d0>)

# %%
for conta in contas:
  print(conta)
# Out:
# [>> Codigo: 15 Saldo: 500 <<]
# [>> Codigo: 234876 Saldo: 1000 <<]

# %%
contas[0].deposita(300)

# %%
for conta in contas:
  print(conta)
# Out:
# [>> Codigo: 15 Saldo: 800 <<]
# [>> Codigo: 234876 Saldo: 1000 <<]

# %% [markdown]
# ### Cap 3: Poliformismo e Arrays

# %%
from abc import ABCMeta, abstractmethod

class Conta(metaclass=ABCMeta):
  def __init__(self, codigo):
    self._codigo = codigo
    self._saldo = 0

  def deposita(self, valor):
    self._saldo+=valor

  @abstractmethod
  def passa_o_mes(self):
    pass

  def __str__(self):
    return "[>> Codigo: {} Saldo: {} <<]".format(self._codigo, self._saldo)

# %%
print (Conta(88))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-35d22dc395ad> in <module>()
# ----> 1 print (Conta(88))
#
# TypeError: Can't instantiate abstract class Conta with abstract methods passa_o_mes

# %%
class ContaCorrente(Conta):
  def passa_o_mes(self):
    self._saldo -= 2

class ContaPoupanca(Conta):
  def passa_o_mes(self):
    self._saldo *=1.01
    self._saldo -=3 

class ContaInvestimento(Conta):
    pass

# %%
conta16 = ContaCorrente(16)
conta16.deposita(1000)
conta16.passa_o_mes()
print(conta16)
# Out:
# [>> Codigo: 16 Saldo: 998 <<]

# %%
conta17 = ContaPoupanca(17)
conta17.deposita(1000)
conta17.passa_o_mes()
print(conta17)
# Out:
# [>> Codigo: 17 Saldo: 1007.0 <<]

# %%
conta16 = ContaCorrente(16)
conta16.deposita(1000)
conta17 = ContaPoupanca(17)
conta17.deposita(1000)
contas = [conta16, conta17]

for conta in contas:
  conta.passa_o_mes()
  print(conta)
# Out:
# [>> Codigo: 16 Saldo: 998 <<]
# [>> Codigo: 17 Saldo: 1007.0 <<]

# %%
ContaInvestimento(40)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-3ad8add2b96b> in <module>()
# ----> 1 ContaInvestimento(40)
#
# TypeError: Can't instantiate abstract class ContaInvestimento with abstract methods passa_o_mes

# %%
import array as arr
arr.array('d', [1,3.5])
# Out:
# array('d', [1.0, 3.5])

# %%
import numpy as np

numeros = np.array([1,3.5])
numeros
# Out:
# array([1. , 3.5])

# %% [markdown]
# ### Cap 4: Igualdade

# %%
class ContaSalario:
  def __init__(self, codigo):
    self._codigo = codigo
    self._saldo = 0

  def __eq__(self, outro):
    return self._codigo == outro._codigo and self._saldo == outro._saldo
  
  def deposita(self, valor):
    self._saldo += valor

  def __str__(self):
    return "[>> Codigo: {}, Saldo: {} <<]".format(self._codigo, self._saldo)

# %%
conta1 = ContaSalario(37)
print(conta1)
# Out:
# [>> Codigo: 37, Saldo: 0 <<]

# %%
conta2 = ContaSalario(37)
print(conta2)
# Out:
# [>> Codigo: 37, Saldo: 0 <<]

# %%
conta1 == conta2
# Out:
# True

# %%
contas = [conta1]
conta1 in contas
# Out:
# True

# %%
conta2 in contas
# Out:
# True

# %%
conta1 = ContaSalario(37)
conta2 = ContaSalario(37)
conta1 == conta2
# Out:
# True

# %%
conta != conta2
# Out:
# True

# %%
conta1 in [conta2]
conta2 in [conta1]
# Out:
# True

# %%
conta1.deposita(10)
conta1==conta2
# Out:
# False

# %%
class ContaSalario:
  def __init__(self, codigo):
    self._codigo = codigo
    self._saldo = 0

  def __eq__(self, outro):
    if type(outro) != ContaSalario:
      return False
    return self._codigo == outro._codigo and self._saldo == outro._saldo
  
  def deposita(self, valor):
    self._saldo += valor

  def __str__(self):
    return "[>> Codigo: {}, Saldo: {} <<]".format(self._codigo, self._saldo)

# %%
conta1 = ContaSalario(37)
conta2 = ContaCorrente(37)
conta1 == conta2
# Out:
# False

# %%
class ContaSalario:
  def __init__(self, codigo):
    self._codigo = codigo
    self._saldo = 0

  def __eq__(self, outro):
    if type(outro) != ContaSalario:
      return False
    return self._codigo == outro._codigo and self._saldo == outro._saldo
  
  def deposita(self, valor):
    self._saldo += valor

  def __str__(self):
    return "[>> Codigo: {}, Saldo: {} <<]".format(self._codigo, self._saldo)

class ContaMultiploSalario(ContaSalario):
  pass

# %%
isinstance(ContaCorrente(34), ContaCorrente)
# Out:
# True

# %%
isinstance(ContaCorrente(34), Conta)
# Out:
# True

# %% [markdown]
# ###Cap 5: Outros builtins

# %%
idades = [15, 87, 32, 65, 56, 32, 49, 37]
for i in range(len(idades)):
  print(i, idades[i])
# Out:
# 0 15
# 1 87
# 2 32
# 3 65
# 4 56
# 5 32
# 6 49
# 7 37

# %%
range(len(idades)) #lazy
# Out:
# range(0, 8)

# %%
enumerate(idades) #lazy

# %%
list(range(len(idades)))
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7]

# %%
list(enumerate(idades))
# Out:
# [(0, 15), (1, 87), (2, 32), (3, 65), (4, 56), (5, 32), (6, 49), (7, 37)]

# %%
for indice, idade in enumerate(idades):
  print (indice, "x", idade) #unpacking da tupla
# Out:
# 0 x 15
# 1 x 87
# 2 x 32
# 3 x 65
# 4 x 56
# 5 x 32
# 6 x 49
# 7 x 37

# %%
usuarios = (
    ("Guilherme", 37, 1981),
    ("Daniela", 31, 1987), 
    ("Paulo", 39, 1979)
)

for nome, idade, nascimento in usuarios:
  print(nome)
# Out:
# Guilherme
# Daniela
# Paulo

# %%
for nome, _ , _ in usuarios:
  print(nome)
# Out:
# Guilherme
# Daniela
# Paulo

# %% [markdown]
# ### Cap 6:  Ordem natural

# %%
idades
# Out:
# [15, 87, 32, 65, 56, 32, 49, 37]

# %%
sorted(idades) #para ordenar os itens por comparacao
# Out:
# [15, 32, 32, 37, 49, 56, 65, 87]

# %%
list(reversed(idades)) #inverte a ordem de sequencia
# Out:
# [37, 49, 32, 56, 65, 32, 87, 15]

# %%
sorted(idades, reverse=True) #ordenado e invertido (ja devolve a lista)
# Out:
# [87, 65, 56, 49, 37, 32, 32, 15]

# %%
list(reversed(sorted(idades)))
# Out:
# [87, 65, 56, 49, 37, 32, 32, 15]

# %%
idades
# Out:
# [15, 87, 32, 65, 56, 32, 49, 37]

# %%
idades.sort()
idades
# Out:
# [15, 32, 32, 37, 49, 56, 65, 87]

# %% [markdown]
# ### Cap 7: Ordenação customizada

# %%
nomes = ["Guilherme", "Daniela", "Paulo"]
sorted(nomes)
# Out:
# ['Daniela', 'Guilherme', 'Paulo']

# %%
class ContaSalario:
  def __init__(self, codigo):
    self._codigo = codigo
    self._saldo = 0

  def __eq__(self, outro):
    if type(outro) != ContaSalario:
      return False
    return self._codigo == outro._codigo and self._saldo == outro._saldo
  
  def __lt__(self, outro):
    return self._saldo < outro._saldo

  def deposita(self, valor):
    self._saldo += valor

  def __str__(self):
    return "[>> Codigo: {}, Saldo: {} <<]".format(self._codigo, self._saldo)

# %%
contaG = ContaSalario(17)
contaG.deposita(500)

contaD = ContaSalario(3)
contaD.deposita(1000)

contaP = ContaSalario(133)
contaP.deposita(510)

contas = [contaG, contaD, contaP]

# %%
for conta in contas:
  print(conta)
# Out:
# [>> Codigo: 17, Saldo: 500 <<]
# [>> Codigo: 3, Saldo: 1000 <<]
# [>> Codigo: 133, Saldo: 510 <<]

# %%
def extrai_saldo(conta):
  return conta._saldo #nao é correto
for conta in sorted(contas, key=extrai_saldo):
  print(conta)
# Out:
# [>> Codigo: 17, Saldo: 500 <<]
# [>> Codigo: 133, Saldo: 510 <<]
# [>> Codigo: 3, Saldo: 1000 <<]

# %%
from operator import attrgetter

for conta in sorted(contas, key=attrgetter("_saldo")):
  print(conta)
# Out:
# [>> Codigo: 17, Saldo: 500 <<]
# [>> Codigo: 133, Saldo: 510 <<]
# [>> Codigo: 3, Saldo: 1000 <<]

# %%
contaG < contaD
# Out:
# True

# %%
contaG > contaD
# Out:
# False

# %%
for conta in sorted(contas):
  print(conta)
# Out:
# [>> Codigo: 17, Saldo: 500 <<]
# [>> Codigo: 133, Saldo: 510 <<]
# [>> Codigo: 3, Saldo: 1000 <<]

# %%
for conta in sorted(contas, reverse=True):
  print(conta)
# Out:
# [>> Codigo: 3, Saldo: 1000 <<]
# [>> Codigo: 133, Saldo: 510 <<]
# [>> Codigo: 17, Saldo: 500 <<]

# %% [markdown]
# ### Cap 8: Ordenação Total

# %%
class ContaSalario:
  def __init__(self, codigo):
    self._codigo = codigo
    self._saldo = 0

  def __eq__(self, outro):
    if type(outro) != ContaSalario:
      return False
    return self._codigo == outro._codigo and self._saldo == outro._saldo
  
  def __lt__(self, outro):
    return self._saldo < outro._saldo

  def deposita(self, valor):
    self._saldo += valor

  def __str__(self):
    return "[>> Codigo: {}, Saldo: {} <<]".format(self._codigo, self._saldo)

# %%
# Ordenação por valores iguais

contaG = ContaSalario(1700)
contaG.deposita(500)

contaD = ContaSalario(3)
contaD.deposita(1000)

contaP = ContaSalario(133)
contaP.deposita(500)

contas = [contaG, contaD, contaP]

# %%
from operator import attrgetter

for conta in sorted(contas, key=attrgetter("_saldo", "_codigo")):
  print(conta)
# Out:
# [>> Codigo: 133, Saldo: 500 <<]
# [>> Codigo: 1700, Saldo: 500 <<]
# [>> Codigo: 3, Saldo: 1000 <<]

# %%
class ContaSalario:
  def __init__(self, codigo):
    self._codigo = codigo
    self._saldo = 0

  def __eq__(self, outro):
    if type(outro) != ContaSalario:
      return False
    return self._codigo == outro._codigo and self._saldo == outro._saldo
  
  def __lt__(self, outro):
    if self._saldo !=outro._saldo:
      return self._saldo < outro._saldo
    return self._codigo < outro._codigo #compara os codigos

  def deposita(self, valor):
    self._saldo += valor

  def __str__(self):
    return "[>> Codigo: {}, Saldo: {} <<]".format(self._codigo, self._saldo)

# %%
for conta in sorted(contas):
  print(conta)
# Out:
# [>> Codigo: 1700, Saldo: 500 <<]
# [>> Codigo: 133, Saldo: 500 <<]
# [>> Codigo: 3, Saldo: 1000 <<]

# %%
contaG = ContaSalario(1700)
contaG.deposita(500)

contaD = ContaSalario(3)
contaD.deposita(1000)

contaP = ContaSalario(133)
contaP.deposita(500)

contas = [contaG, contaD, contaP]

# %%
for conta in sorted(contas):
  print(conta)
# Out:
# [>> Codigo: 133, Saldo: 500 <<]
# [>> Codigo: 1700, Saldo: 500 <<]
# [>> Codigo: 3, Saldo: 1000 <<]

# %%
contaG <= contaD
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-bfd6f5ff0f9b> in <module>()
# ----> 1 contaG <= contaD
#
# TypeError: '<=' not supported between instances of 'ContaSalario' and 'ContaSalario'

# %%
from functools import total_ordering

@total_ordering
class ContaSalario:
  def __init__(self, codigo):
    self._codigo = codigo
    self._saldo = 0

  def __eq__(self, outro):
    if type(outro) != ContaSalario:
      return False
    return self._codigo == outro._codigo and self._saldo == outro._saldo
  
  def __lt__(self, outro):
    if self._saldo !=outro._saldo:
      return self._saldo < outro._saldo
    return self._codigo < outro._codigo #compara os codigos

  def deposita(self, valor):
    self._saldo += valor

  def __str__(self):
    return "[>> Codigo: {}, Saldo: {} <<]".format(self._codigo, self._saldo)

# %%
contaG = ContaSalario(1700)
contaG.deposita(500)

contaD = ContaSalario(3)
contaD.deposita(1000)

contaP = ContaSalario(133)
contaP.deposita(500)

contas = [contaG, contaD, contaP]

# %%
#a função total ordering permite essas comparações com => <= e ==
contaG <= contaD
contaG <= contaP
contaG < contaG
contaG == contaG
contaG <= contaG
# Out:
# True
